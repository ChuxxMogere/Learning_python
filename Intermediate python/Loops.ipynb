# %% [markdown]
# 1. While loop
# #The while loop is like a repeated if statement. The code is executed over and over again, as long as the condition is True

# %%
x = 1
while x < 4 :
    print(x)
    x = x + 1
# Out:
# 1
# 2
# 3

# %%
#Code a while loop that keeps running as long as offset is not equal to 0.
# Initialize offset
offset = 8

# Code the while loop
while offset != 0 :
    print("correcting...")
    offset = offset -1
    print(offset)
# Out:
# correcting...
# 7
# correcting...
# 6
# correcting...
# 5
# correcting...
# 4
# correcting...
# 3
# correcting...
# 2
# correcting...
# 1
# correcting...
# 0

# %%
# Adding conditionals to a while loop

 #Inside the while loop, complete the if-else statement:
   #If offset is greater than zero, you should decrease offset by 1.
     #Else, you should increase offset by 1.

offset = -6
while offset != 0:
    print("correting...")
    if offset > 0 :
        offset = offset - 1
    else:
        offset = offset + 1
    print(offset)
# Out:
# correting...
# -5
# correting...
# -4
# correting...
# -3
# correting...
# -2
# correting...
# -1
# correting...
# 0

# %% [markdown]
# For Loop
# Its syntax is :
#  for element_variable in iterable_object :
#      <block(s) of code>
# . element_variable = variable assigned to each iterable element. Can be any name
# . iterable_object = an iterable object and can also be referenced by a variable name

# %%
# Loop over a list
# Write a for loop that iterates over all elements of the areas list and prints out every element separately.

areas = [11.25, 18.0, 20.0, 10.75, 9.50]

#code for loop
for area in areas :
    print(area)
# Out:
# 11.25
# 18.0
# 20.0
# 10.75
# 9.5

# %%
# Doing increment with for loop

list_1 = [0, 2, 4, 6, 8]
num = 0

for x in list_1 :
    print(num)
    num = num + 1 # can be written as (num+=1)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# The order of where you place num matters as :

num = 0
for x in list_1 :
    num = num + 1  # num is incremented before it is printed. So num begins with 1 instead of 0
    print(num)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# for loop  in an embedded list

list_2 = [[1,2],[3,4],[5,6]]

for x in list_2 :
    print(x)
# Out:
# [1, 2]
# [3, 4]
# [5, 6]

# %%
# Accessing only the fisrt element in the list

for x in list_2 :
    print(x[0])   # x[1] returns the second elements in each embedded list
# Out:
# 1
# 3
# 5

# %%
# Accessing all elements in the list

for x in list_2 :
    print(x[0])
    print(x[1])
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
# You could also do thia to get the above results

for x in list_2 :
    for y in x :
        print(y)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
# Unpacking in a for loop( Involves assigneing a variable to each element

for a,b in list_2:
    print(a)
    print(b)

# The above works for tuples, sets, strings
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
# for loop in dictionaries

dict_1 = {'key_1':'value_1', 'key_2':'value_2'}

for k,v in dict_1.items():
    print(k)
    print(v)
# Out:
# key_1
# value_1
# key_2
# value_2

# %%
# Excluding something from a list

furniture = ['sofa', 'desk','lamp','tv']
for x in furniture:
    if x != 'tv':
        print(x)
# Out:
# sofa
# desk
# lamp

# %%
# Indexes and values
# If you want to access the index information, so where the list element you're iterating over is located, you can use enumerate().

areas = [11.25, 18.0, 20.0, 10.75, 9.50]

for room, area in enumerate(areas) :
    print("room " + str(room)+ " : " + str(area))
# Out:
# room 0 : 11.25
# room 1 : 18.0
# room 2 : 20.0
# room 3 : 10.75
# room 4 : 9.5

# %%
# For non-programmer folks, room 0: 11.25 is strange. Wouldn't it be better if the count started at 1?

areas = [11.25, 18.0, 20.0, 10.75, 9.50]

for x, y in enumerate(areas, start = 1) :
    print("room " + str(x)+ " : " + str(y))
# Out:
# room 1 : 11.25
# room 2 : 18.0
# room 3 : 20.0
# room 4 : 10.75
# room 5 : 9.5

# %%
# Loop over list of lists
# Write a for loop that goes through each sublist of house and prints out the x is y sqm, where x is the name of the room and y is the area of the room.

house = [["hallway", 11.25], 
         ["kitchen", 18.0], 
         ["living room", 20.0], 
         ["bedroom", 10.75], 
         ["bathroom", 9.50]]

for x, y in house :
    print("The " + str(x) + " is " + str(y) + " sqm")
    # Alternatives
    #print(room + " is " + str(area))
    #print(room,area)
# Out:
# The hallway is 11.25 sqm
# The kitchen is 18.0 sqm
# The living room is 20.0 sqm
# The bedroom is 10.75 sqm
# The bathroom is 9.5 sqm

# %%
# Loop over a dictionary

# The dictionary
europe = {'spain':'madrid', 'france':'paris', 'germany':'berlin',
          'norway':'oslo', 'italy':'rome', 'poland':'warsaw', 'austria':'vienna' }
          
# Iterate over europe
for k, v in europe.items() :
    print("The capital of " + str(k) + " is " + str(v))
# Out:
# The capital of spain is madrid
# The capital of france is paris
# The capital of germany is berlin
# The capital of norway is oslo
# The capital of italy is rome
# The capital of poland is warsaw
# The capital of austria is vienna

# %%
# Loop over numpy array
# 1D array

import numpy as np
heights = height_in = [74, 74, 72, 72, 73, 69, 69, 71, 76, 71, 73, 73, 74, 74, 69, 70, 73]
np_height = np.array(heights)

# For loop over np_height
for value in np_height :
    print(str(value) + " inches")
# Out:
# 74 inches
# 74 inches
# 72 inches
# 72 inches
# 73 inches
# 69 inches
# 69 inches
# 71 inches
# 76 inches
# 71 inches
# 73 inches
# 73 inches
# 74 inches
# 74 inches
# 69 inches
# 70 inches
# 73 inches

# %%
# 2D array
baseball = [[180, 78.4],
            [215, 102.7],
            [210, 98.5],
            [188, 75.2]]

np_baseball = np.array(baseball)

# For loop over np_baseball
for value in np.nditer(np_baseball) :
    print(value)
# Out:
# 180.0
# 78.4
# 215.0
# 102.7
# 210.0
# 98.5
# 188.0
# 75.2

# %%
# Loop over DataFrame
# for loop that iterates over the rows of cars and on each iteration perform two print() calls:
# one to print out the row label and one to print out all of the rows contents.

import pandas as pd
cars = pd.read_csv("C:/Users/chux/Documents/Python/cars.csv", index_col = 0)

for lab,row in cars.iterrows():
    print(lab) #These are the row index names
    print(row) #These are the entire detail of each row
# Out:
# US
# cars_per_cap              809
# country         United States
# drives_right             True
# Name: US, dtype: object
# AUS
# cars_per_cap          731
# country         Australia
# drives_right        False
# Name: AUS, dtype: object
# JPN
# cars_per_cap      588
# country         Japan
# drives_right    False
# Name: JPN, dtype: object
# IN
# cars_per_cap       18
# country         India
# drives_right    False
# Name: IN, dtype: object
# RU
# cars_per_cap       200
# country         Russia
# drives_right      True
# Name: RU, dtype: object
# MOR
# cars_per_cap         70
# country         Morroco
# drives_right       True
# Name: MOR, dtype: object
# EG
# cars_per_cap       45
# country         Egypt
# drives_right     True
# Name: EG, dtype: object

# %%
# Loop over dataframe 2
# The row data that's generated by iterrows() on every run is a Pandas Series. This format is not very convenient to print out.

cars = pd.read_csv("C:/Users/chux/Documents/Python/cars.csv", index_col = 0)

# Using the iterators lab and row, adapt the code in the for loop such that the first iteration prints out "US: 809"
for lab, row in cars.iterrows():
    print(lab + ": " + str(row['cars_per_cap'])) # Adding the str on row since the column contains integers
    #print(lab + ": " + row['country'])  #For a column that has integers, no need of adding str()
# Out:
# US: 809
# AUS: 731
# JPN: 588
# IN: 18
# RU: 200
# MOR: 70
# EG: 45

# %%
# Adding a column to a dataframe
# for loop to add a new column, named COUNTRY, that contains a uppercase version of the country names in the "country" column. 

for lab, row in cars.iterrows():
    cars.loc[lab, "COUNTRY"] = row['country'].upper()
print(cars)
# Out:
#      cars_per_cap        country  drives_right        COUNTRY
# US            809  United States          True  UNITED STATES
# AUS           731      Australia         False      AUSTRALIA
# JPN           588          Japan         False          JAPAN
# IN             18          India         False          INDIA
# RU            200         Russia          True         RUSSIA
# MOR            70        Morroco          True        MORROCO
# EG             45          Egypt          True          EGYPT

# %%
# Adding a column without using a for loop
# Using the apply() method is easier

cars = pd.read_csv("C:/Users/chux/Documents/Python/cars.csv", index_col = 0)

cars["COUNTRY"] = cars["country"].apply(str.upper)
print(cars)
# Out:
#      cars_per_cap        country  drives_right        COUNTRY
# US            809  United States          True  UNITED STATES
# AUS           731      Australia         False      AUSTRALIA
# JPN           588          Japan         False          JAPAN
# IN             18          India         False          INDIA
# RU            200         Russia          True         RUSSIA
# MOR            70        Morroco          True        MORROCO
# EG             45          Egypt          True          EGYPT
