# %%
# Python lists are a compound data type
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50

areas = [11.25, 18.0, 20.0, 10.75, 9.50]
print(areas)
# Out:
# [11.25, 18.0, 20.0, 10.75, 9.5]
