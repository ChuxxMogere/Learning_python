# %%
#Python as a calculator(Interpretes what've typed and prints results
4 + 5
#(Prints 9)
# Out:
# 9

# %%
#Python scripts (Maintains structure of your code)

# %%
print(4+5)
print(5/8)
# Out:
# 9
# 0.625

# %%
# Variables and types (Assigning variable names and calling them out)
height = 1.79
weight = 58.9
print(height)
# Displays 1.79 as result
# Out:
# 1.79

# %%
bmi = weight / height **2
print(bmi)
# Calculates the bmi
# Out:
# 18.382697169251895

# %%
# Data types
# float
half = 0.5

# string
intro = "Hello! How are you?"

#boolen
is_good = True

# To know the type of the variable use
print(type(half))
print(type(intro))
# Out:
# <class 'float'>
# <class 'str'>

# %%
# Addind strings
doubleintro = intro + intro
print(doubleintro)
# The results are (Hello! How are you?Hello! How are you?)
# Out:
# Hello! How are you?Hello! How are you?
